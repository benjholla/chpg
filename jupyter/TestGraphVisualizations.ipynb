// %%
%jars chpg.jar
%jars chpg-visualizations.jar
import chpg.graph.*;
import chpg.graph.schema.*;
import chpg.visualizations.GraphView;

import java.util.List;
import java.util.ArrayList;
import java.util.Random;

// %%
Graph graph = new PropertyGraph();

List<Node> nodes = new ArrayList<Node>();
for(int i=0; i<30; i++){
  Node n = new Node();
  graph.add(n);
  nodes.add(n);
}

Random rnd = new Random();
for(int i=0; i<35; i++){
  Edge e = new Edge(nodes.get(rnd.nextInt(30)), nodes.get(rnd.nextInt(30)));
  graph.add(e);
}

GraphView.show(graph);
// Out:
// <html><iframe src='/var/folders/p3/kkl7xkvj3vqddl60474ym2sc0000gn/T/graph-viewer6081039063179788895/index.html' width="100%", height="600px" frameBorder="0"></iframe></html>
